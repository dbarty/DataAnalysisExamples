# %% [markdown]
# # Visualisation: Subplots
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplot.html

# %% [markdown]
# ## Import Modules

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Simple Subplot Example

# %%
# Example from book "Numerisches PYTHON"
rows, cols = 2, 3
fig, ax = plt.subplots(rows, cols, sharex="col", sharey="row")

for row in range(rows):
    for col in range(cols):
        ax[row, col].text(0.5, 0.5, str((row, col)), color="green", fontsize=18, ha="center")

# %%
# Example from book "Numerisches PYTHON"
x = np.linspace(0, 2 * np.pi, 400)
y = np.sin(x**2) + np.cos(x)
derivative = 2 + x + np.cos(x**2) - np.sin(x)

rows, cols = 2, 2
fig, axes = plt.subplots(rows, cols, subplot_kw=dict(polar=True))
fig.suptitle("Various Plots")

axes[0, 0].set(title="sin(x) + cos(x)")
axes[0, 0].plot(x, y)

axes[0, 1].set(title="derivative")
axes[0, 1].plot(x, np.sin(x**2) + np.cos(x**3))
axes[1, 0].set(title="cos(x) + sin(x^2)")
axes[1, 0].plot(x, np.cos(x) + np.sin(x**2))
axes[1, 1].set(title="derivative")
axes[1, 1].plot(x, derivative, "g--")

plt.subplots_adjust(left=0, right=1, bottom=0, top=0.8, wspace=0.0, hspace=0.8)import seaborn as sns
import matplotlib.pyplot as plt

# Laden des Datensatzes
df = sns.load_dataset("penguins")

# Erstellen eines Subplot-Rasters mit 2x2
fig, axs = plt.subplots(2, 2, figsize=(14, 12))

# Gemeinsame Einstellungen für die Plots
plot_args = dict(x="bill_length_mm", y="flipper_length_mm")

# Scatterplot und Marginalverteilungen für species (links oben)
sns.scatterplot(data=df, hue="species", ax=axs[0, 0], **plot_args)
sns.histplot(data=df, ax=axs[0, 0].margins(), x="bill_length_mm", hue="species", element="step", kde=True)
sns.histplot(data=df, ax=axs[0, 1,m ans
